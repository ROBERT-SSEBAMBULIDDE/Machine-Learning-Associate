# %% [markdown]
# <a href="https://colab.research.google.com/github/ROBERT-SSEBAMBULIDDE/Machine-Learning-Associate/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LINEAR REGRESSION**

# %% [markdown]
# Linear Regression is one of the simplest and most widely used supervised learning algorithms. It’s particularly useful for predicting a continuous variable (target) based on one or more explanatory variables (features).
#
# Linear Regression tries to find a linear relationship between the independent (input) variables 𝑋 and the dependent (output) variable 𝑌
# . The basic goal is to model this relationship using a straight line.
#
# Y=β
# 0
# ​
#  +β
# 1
# ​
#  X+ϵ

# %% [markdown]
# ![Screenshot.png](data:image/png;base64,...)

# %% [markdown]
# # **Mathematics Behind Linear Regression**
#
# To estimate the best values of
# 𝛽
# 0 and
# 𝛽
# 1
# , we minimize the sum of squared residuals (SSR) between the actual and predicted values, called Ordinary Least Squares (OLS).
#
# The formula for the line that minimizes the SSR is:
#
# ![Screenshot.png](data:image/png;base64,...)

# %% [markdown]
# # **Assumptions in Linear Regression**
# Before applying linear regression, it’s essential to check the following assumptions:
#
# **Linearity:** The relationship between
# X and
# Y is linear.
#
# **Independence**: Observations should be independent of each other.
#
# **Homoscedasticity:** The variance of residuals is constant.
#
# **Normality**: Residuals should be normally distributed.
#
# **No Multicollinearity**: For multiple linear regression, independent variables should not be highly correlated with each other.

# %% [markdown]
# # **Data Preprocessing**
# **Data Cleaning**: Handle missing values, correct data types, and remove outliers if necessary.
#
# **Feature Selection**: Choose the variables that are relevant to the target.
#
# **Feature Scaling**: Standardize or normalize features for better performance, especially for multiple linear regression.

# %% [markdown]
# # **Implementing Linear Regression in Python**
# Implement a simple linear regression model with Python using scikit-learn.
